# %% [markdown]
# # Taking a look at our Standard Player data #
#
# Here we will take a quick look at the standard player metrics collected. This data includes things much of the traditional, and likely most important data we have. It includes metrics like goals, assists, points, +/-, and more.

# %%
import pandas as pd
from per_60_functions import per_60_to_totals, per_60_to_GP
import os

# %%
# Load bio data from directory "../../Data/NHL_PlayerData_NatrualStatTrick/oi" using pandas dataframe

directory = "../../Data/NHL_PlayerData_NaturalStatTrick/std"

std_df = pd.DataFrame()

for year in range(2007, 2025):
    filename = f'regSeason_allStrengths_allScores_std_{year}.csv'
    df = pd.read_csv(f'{directory}/{filename}')
    # Concatenate dataframes with bio_df
    std_df = pd.concat([std_df, df])

std_df.head(-5)
# Out:
#      Year         Player      Team Position  GP          TOI     TOI/GP  \
# 0    2007   Aaron Downey       DET        R  56   256.933333   4.588095
# 1    2007  Aaron Johnson       NYI        D  30   415.850000  13.861667
# 2    2007   Aaron Miller       VAN        D  57   988.183333  17.336550
# 3    2007     Aaron Rome       CBJ        D  17   309.033333  18.178431
# 4    2007    Aaron Voros       MIN        L  55   504.600000   9.174545
# ..    ...            ...       ...      ...  ..          ...        ...
# 876  2024      Zach Dean       STL        C   1     8.683333   8.683333
# 877  2024     Zach Hyman       EDM        L  66  1292.750000  19.587121
# 878  2024    Zach Parise       COL        L  17   234.533333  13.796078
# 879  2024   Zach Sanford  ARI, CHI        L  29   314.266667  10.836782
# 880  2024  Zach Werenski       CBJ        D  57  1389.816667  24.382749
#
#      Goals/60  Total Assists/60  First Assists/60  ...  Misconduct/60  \
# 0        0.00              0.70              0.70  ...           0.47
# 1        0.00              0.29              0.00  ...           0.00
# 2        0.06              0.49              0.06  ...           0.06
# 3        0.19              0.19              0.00  ...           0.19
# 4        0.83              0.83              0.71  ...           0.24
# ..        ...               ...               ...  ...            ...
# 876      0.00              0.00              0.00  ...           0.00
# 877      2.23              0.88              0.46  ...           0.00
# 878      1.02              0.77              0.51  ...           0.00
# 879      0.00              1.15              0.95  ...           0.00
# 880      0.22              1.64              0.69  ...           0.00
#
#      Penalties Drawn/60 Giveaways/60  Takeaways/60 Hits/60  Hits Taken/60  \
# 0                  4.90         0.93          0.70   18.45          11.21
# 1                  0.58         2.31          2.60    5.92           5.63
# 2                  0.24         1.76          0.91    2.25           4.49
# 3                  0.97         0.78          0.39    6.41           4.27
# 4                  3.80         1.19          0.95   11.41           7.97
# ..                  ...          ...           ...     ...            ...
# 876                0.00         0.00          6.91    0.00           6.91
# 877                0.88         0.74          1.53    2.27           5.80
# 878                0.26         0.26          1.53    3.33           4.86
# 879                0.57         1.15          3.05    3.63           5.73
# 880                0.09         0.99          1.21    0.65           1.34
#
#      Shots Blocked/60  Faceoffs Won/60  Faceoffs Lost/60  Faceoffs %
# 0                1.40             0.00              0.00           -
# 1                4.04             0.00              0.00           -
# 2                4.86             0.00              0.00           -
# 3                3.30             0.00              0.00           -
# 4                0.59             0.36              1.43        2.38
# ..                ...              ...               ...         ...
# 876              0.00             6.91             13.82      230.33
# 877              1.58             0.32              0.42        2.03
# 878              3.33             2.56              4.86        8.82
# 879              3.63             8.02             14.70        6.74
# 880              4.71             0.00              0.00           -
#
# [16108 rows x 36 columns]

# %%
std_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16113 entries, 0 to 885
# Data columns (total 36 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Year                 16113 non-null  int64
#  1   Player               16113 non-null  object
#  2   Team                 16113 non-null  object
#  3   Position             16113 non-null  object
#  4   GP                   16113 non-null  int64
#  5   TOI                  16113 non-null  float64
#  6   TOI/GP               16113 non-null  float64
#  7   Goals/60             16113 non-null  float64
#  8   Total Assists/60     16113 non-null  float64
#  9   First Assists/60     16113 non-null  float64
#  10  Second Assists/60    16113 non-null  float64
#  11  Total Points/60      16113 non-null  float64
#  12  IPP                  16113 non-null  object
#  13  Shots/60             16113 non-null  float64
#  14  SH%                  16113 non-null  object
#  15  ixG/60               16113 non-null  float64
#  16  iCF/60               16113 non-null  float64
#  17  iFF/60               16113 non-null  float64
#  18  iSCF/60              16113 non-null  float64
#  19  iHDCF/60             16113 non-null  float64
#  20  Rush Attempts/60     16113 non-null  float64
#  21  Rebounds Created/60  16113 non-null  float64
#  22  PIM/60               16113 non-null  float64
#  23  Total Penalties/60   16113 non-null  float64
#  24  Minor/60             16113 non-null  float64
#  25  Major/60             16113 non-null  float64
#  26  Misconduct/60        16113 non-null  float64
#  27  Penalties Drawn/60   16113 non-null  float64
#  28  Giveaways/60         16113 non-null  float64
#  29  Takeaways/60         16113 non-null  float64
#  30  Hits/60              16113 non-null  float64
#  31  Hits Taken/60        16113 non-null  float64
#  32  Shots Blocked/60     16113 non-null  float64
#  33  Faceoffs Won/60      16113 non-null  float64
#  34  Faceoffs Lost/60     16113 non-null  float64
#  35  Faceoffs %           16113 non-null  object
# dtypes: float64(28), int64(2), object(6)
# memory usage: 4.5+ MB

# %% [markdown]
# Here we see that given 15227 rows, not a single column has a null entry, which is again fantastic.n Let's take a look at each of the columns to try to recognize if the values make sense.

# %%
# Use .describe() to get summary statistics of the data in a way that we view all columns

std_df.describe()
# Out:
#                Year            GP           TOI        TOI/GP      Goals/60  \
# count  16113.000000  16113.000000  16113.000000  16113.000000  16113.000000
# mean    2015.604419     47.177807    778.430285     14.982490      0.496651
# std        5.183898     27.806134    553.378814      4.554586      0.527633
# min     2007.000000      1.000000      0.750000      0.750000      0.000000
# 25%     2011.000000     20.000000    237.900000     11.667521      0.090000
# 50%     2016.000000     53.000000    784.850000     15.010833      0.390000
# 75%     2020.000000     72.000000   1228.883333     18.246753      0.780000
# max     2024.000000     85.000000   2411.950000     29.414024     15.840000
#
#        Total Assists/60  First Assists/60  Second Assists/60  Total Points/60  \
# count      16113.000000      16113.000000       16113.000000     16113.000000
# mean           0.816885          0.450256           0.366641         1.313563
# std            0.637831          0.438511           0.380833         0.941622
# min            0.000000          0.000000           0.000000         0.000000
# 25%            0.420000          0.140000           0.130000         0.660000
# 50%            0.760000          0.390000           0.330000         1.200000
# 75%            1.140000          0.660000           0.520000         1.860000
# max           12.370000          9.890000          12.370000        15.840000
#
#            Shots/60  ...      Major/60  Misconduct/60  Penalties Drawn/60  \
# count  16113.000000  ...  16113.000000   16113.000000        16113.000000
# mean       5.849258  ...      0.149402       0.035031            0.877195
# std        2.721122  ...      0.626152       0.272973            1.138037
# min        0.000000  ...      0.000000       0.000000            0.000000
# 25%        3.990000  ...      0.000000       0.000000            0.340000
# 50%        5.690000  ...      0.000000       0.000000            0.650000
# 75%        7.520000  ...      0.060000       0.000000            1.070000
# max       35.290000  ...     22.090000      13.280000           41.860000
#
#        Giveaways/60  Takeaways/60       Hits/60  Hits Taken/60  \
# count  16113.000000  16113.000000  16113.000000   16113.000000
# mean       1.522993      1.343703      5.550889       5.091776
# std        1.070373      1.009584      4.690641       2.808683
# min        0.000000      0.000000      0.000000       0.000000
# 25%        0.950000      0.730000      2.350000       3.380000
# 50%        1.420000      1.250000      4.280000       4.690000
# 75%        1.980000      1.810000      7.360000       6.280000
# max       21.180000     22.430000     76.600000      83.720000
#
#        Shots Blocked/60  Faceoffs Won/60  Faceoffs Lost/60
# count      16113.000000     16113.000000      16113.000000
# mean           2.721521         5.319401          5.569171
# std            1.947884         9.294357          9.120115
# min            0.000000         0.000000          0.000000
# 25%            1.350000         0.000000          0.000000
# 50%            2.300000         0.200000          0.440000
# 75%            3.810000         6.180000          7.620000
# max           34.290000        51.180000         80.720000
#
# [8 rows x 30 columns]

# %%
std_df.columns
# Out:
# Index(['Year', 'Player', 'Team', 'Position', 'GP', 'TOI', 'TOI/GP', 'Goals/60',
#        'Total Assists/60', 'First Assists/60', 'Second Assists/60',
#        'Total Points/60', 'IPP', 'Shots/60', 'SH%', 'ixG/60', 'iCF/60',
#        'iFF/60', 'iSCF/60', 'iHDCF/60', 'Rush Attempts/60',
#        'Rebounds Created/60', 'PIM/60', 'Total Penalties/60', 'Minor/60',
#        'Major/60', 'Misconduct/60', 'Penalties Drawn/60', 'Giveaways/60',
#        'Takeaways/60', 'Hits/60', 'Hits Taken/60', 'Shots Blocked/60',
#        'Faceoffs Won/60', 'Faceoffs Lost/60', 'Faceoffs %'],
#       dtype='object')

# %%
std_df['Position'].unique()
# Out:
# array(['R', 'D', 'L', 'C', 'C, L', 'L, R', 'C, R', 'D, L'], dtype=object)

# %% [markdown]
# # Converting Rates to Totals
#
# The features of our data are all in rate form, and it occurs to me that it may be useful to utilize the totals for our features, instead of the rates. Here I will convert all features that are in a rate format "feature/60" back to simply "feature".
#
# Something convenient that I noticed is that TOI is already in the correct format. As opposed to minutes:seconds it has already been converted to total minutes

# %%
per_60_columns = std_df.filter(like='/60').columns

totals_df = per_60_to_totals(std_df, per_60_columns)

# Merge std_df with new_df on axis = 1
std_df = pd.concat([std_df, totals_df], axis=1)

# %%
gp_df = per_60_to_GP(std_df, per_60_columns)

std_df = pd.concat([std_df, gp_df], axis=1)

# %%
# Extract all columns that end in '/60'

per_60_columns = std_df.filter(like='/60')

per_GP_columns = std_df.filter(like='/GP')

percentage_columns = std_df.filter(like='%')

# Extract all columns that are not per 60 or per GP

non_per_columns = std_df.drop(per_60_columns.columns, axis=1).drop(per_GP_columns.columns, axis=1).drop(percentage_columns.columns, axis=1)

final_data = pd.concat([non_per_columns, per_GP_columns, per_60_columns, percentage_columns], axis=1)
final_data.columns.tolist()
# Out:
# ['Year',
#  'Player',
#  'Team',
#  'Position',
#  'GP',
#  'TOI',
#  'IPP',
#  'Goals',
#  'Total Assists',
#  'First Assists',
#  'Second Assists',
#  'Total Points',
#  'Shots',
#  'ixG',
#  'iCF',
#  'iFF',
#  'iSCF',
#  'iHDCF',
#  'Rush Attempts',
#  'Rebounds Created',
#  'PIM',
#  'Total Penalties',
#  'Minor',
#  'Major',
#  'Misconduct',
#  'Penalties Drawn',
#  'Giveaways',
#  'Takeaways',
#  'Hits',
#  'Hits Taken',
#  'Shots Blocked',
#  'Faceoffs Won',
#  'Faceoffs Lost',
#  'TOI/GP',
#  'Goals/GP',
#  'Total Assists/GP',
#  'First Assists/GP',
#  'Second Assists/GP',
#  'Total Points/GP',
#  'Shots/GP',
#  'ixG/GP',
#  'iCF/GP',
#  'iFF/GP',
#  'iSCF/GP',
#  'iHDCF/GP',
#  'Rush Attempts/GP',
#  'Rebounds Created/GP',
#  'PIM/GP',
#  'Total Penalties/GP',
#  'Minor/GP',
#  'Major/GP',
#  'Misconduct/GP',
#  'Penalties Drawn/GP',
#  'Giveaways/GP',
#  'Takeaways/GP',
#  'Hits/GP',
#  'Hits Taken/GP',
#  'Shots Blocked/GP',
#  'Faceoffs Won/GP',
#  'Faceoffs Lost/GP',
#  'Goals/60',
#  'Total Assists/60',
#  'First Assists/60',
#  'Second Assists/60',
#  'Total Points/60',
#  'Shots/60',
#  'ixG/60',
#  'iCF/60',
#  'iFF/60',
#  'iSCF/60',
#  'iHDCF/60',
#  'Rush Attempts/60',
#  'Rebounds Created/60',
#  'PIM/60',
#  'Total Penalties/60',
#  'Minor/60',
#  'Major/60',
#  'Misconduct/60',
#  'Penalties Drawn/60',
#  'Giveaways/60',
#  'Takeaways/60',
#  'Hits/60',
#  'Hits Taken/60',
#  'Shots Blocked/60',
#  'Faceoffs Won/60',
#  'Faceoffs Lost/60',
#  'SH%',
#  'Faceoffs %']

# %% [markdown]
# # Save this data to disk

# %%
dir_path = '../../Data/Warehouse/PlayerData/'
filename = 'std.csv'

if not os.path.exists(dir_path):
    os.makedirs(dir_path)

final_data.to_csv(f'{dir_path}/{filename}', index=False)
